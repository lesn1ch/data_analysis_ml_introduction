# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/students.csv')
df.info()

df_cut = df[['Year of birth', 'Growth', 'Weight', 'Hair length', 'Shoe size']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
# df.groupby('Rock paper scissors')[['Russian rating', 'Maths rating']].mean().describe()
# Out:
#        Russian rating  Maths rating
# count        3.000000      3.000000
# mean        80.637440     57.600013
# std          3.822802      4.637519
# min         76.473684     52.894737
# 25%         78.961842     55.316687
# 50%         81.450000     57.738636
# 75%         82.719318     59.952652
# max         83.988636     62.166667

# %% [markdown]
# # Удаление пропусков данных
#
# ```
# df.dropna() #Удаляет все строчки, в которых есть пропуски
# df.fillna(const) #Заменяет все пропуски на значение const
# ```

# %%
fem = df[df['Sex'] == 'женский']
male = df[df['Sex'] == 'мужской']
fem['Weight'] = fem['Weight'].fillna(fem['Weight'].mean())
male['Weight'] = male['Weight'].fillna(male['Weight'].mean())
# (male['Weight'].mean() + fem['Weight'].mean()) / 2
df_new = pd.concat([male, fem])
df_new['Weight'].mean()
# Out:
# <ipython-input-17-2409595e718c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fem['Weight'] = fem['Weight'].fillna(fem['Weight'].mean())
# <ipython-input-17-2409595e718c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male['Weight'] = male['Weight'].fillna(male['Weight'].mean())
# 63.53201161071252

# %%
singles = df[df['Brother-sister'] =='нет ни брата ни сестры']
sublings = df[df['Brother-sister'] !='нет ни брата ни сестры']
9
# singles['Children number'].median(), sublings['Children number'].median()
singles['Children number'] = singles['Children number'].fillna(singles['Children number'].median())
sublings['Children number'] = sublings['Children number'].fillna(sublings['Children number'].median())
df_mew_1 = pd.concat([singles, sublings])
df_mew_1['Children number'].median()
# Out:
# <ipython-input-22-f8f5ca2bed86>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singles['Children number'] = singles['Children number'].fillna(singles['Children number'].median())
# <ipython-input-22-f8f5ca2bed86>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sublings['Children number'] = sublings['Children number'].fillna(sublings['Children number'].median())
# 2.0

# %%
a = df['Putin age'].quantile(.25)
b = df['Putin age'].quantile(.75)
quantile_gap = b - a
a = a - 1.5*quantile_gap
b = b + 1.5*quantile_gap
df = df[(df['Putin age'] > a) & (df['Putin age'] < b)]
len(df)
# sns.boxplot(df['Putin age'])
# Out:
# 69.0
